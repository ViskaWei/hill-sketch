# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# DATASET = '/home/swei20/sketch-scale/data/kmat.xlsx'
# DATASET = '../data/simple/SS-abaqus-data.xlsx'
DATASET = '../data/simple/EE.csv'

# %%
from hillSimple import *

# %%
nCluster = 10
nPCA = 6
isVol = True

# %%
data,kmap,centers = run_hill_simple(DATASET, nCluster, nPCA, name='k', isVol=isVol, isCenter=True, offset=0)
# Out:
# (7560, 6)
# (7560, 2)
# center Id: [5566 2116 5979 5635 2137 4116 2783  375  445 3884]
# cluster volumn sum: 0.0

# %%
len(data.columns)
# Out:
# 41

# %%
data.columns
# Out:
# Index(['k1', 'k2', 'k3', 'k4', 'k5', 'k6', 'k7', 'k8', 'k9', 'k10', 'k11',
#        'k12', 'k13', 'k14', 'k15', 'k16', 'k17', 'k18', 'k19', 'k20', 'k21',
#        'k22', 'k23', 'k24', 'k25', 'k26', 'k27', 'k28', 'k29', 'k30', 'k31',
#        'k32', 'k33', 'k34', 'k35', 'k36', 'C10', 'M10', 'vol', 't1', 't2'],
#       dtype='object')

# %%
plot_data(data,kmap,cut = 2590, rng=50)

# %%
outDir = './out/'

# %%
save_cluster_ids(data, nCluster, outDir=outDir,name='kMat')
# Out:
# Cluster1: [1691 1692 1693]..
# Cluster2: [17 18 63]..
# Cluster3: [1621 1622 1623]..
# Cluster4: [25 26 27]..
# Cluster5: [1109 1188 1189]..
# Cluster6: [1950 1951 1952]..
# Cluster7: [2462 2463 2464]..
# Cluster8: [1 2 3]..
# Cluster9: [33 34 35]..
# Cluster10: [19 20 21]..

# %%
save_centers(centers,nCluster,outDir=outDir,name='centers')

# %%
lbl = data[f'C{nCluster}']
cs = []
for i in range(1,nCluster+1):
    c = np.where(lbl==i)[0]+1  
    cs.append(c.shape)
    print(c.shape)
# Out:
# (718,)
# (966,)
# (742,)
# (668,)
# (686,)
# (558,)
# (922,)
# (692,)
# (842,)
# (766,)

# %%
np.sum(cs)
# Out:
# 7560
